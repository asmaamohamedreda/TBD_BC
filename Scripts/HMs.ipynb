# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
%load_ext rpy2.ipython

# %%
.libPaths(c("/content/drive/MyDrive/Colab Notebooks/R_lib", .libPaths()))
library(dplyr)
library(pheatmap)
library(RColorBrewer)
library(limma)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
metadata = read.csv("/content/metadata_GSE4290")
exp = read.csv("/content/exp_GSE4290", row.names = 1)

# %%
# Scale Data:
exp_scaled_t = scale(t(exp))
exp_scaled = t(exp_scaled_t)

# %%
# Define thresholds for classification
logFC_threshold <- 1
adjPval_threshold <- 0.05

# Generate the heatmap
pheatmap(
  scaled_exp,
  annotation_col = sample_annotation,
  annotation_colors = annotation_colors,
  cluster_rows = TRUE,
  cluster_cols = TRUE,
  show_rownames = TRUE,
  show_colnames = TRUE,
  color = colorRampPalette(c("turquoise1", "white", "red"))(100),
  fontsize_row = 8,
  fontsize_col = 8,
  fontsize = 12,
  border_color = NA,
  main = "Heatmap of Differentially Expressed Genes\n(Oligodendroglioma vs NonTumor)"
)
# Out:
# plot without title

# %%
# Define thresholds for classification
logFC_threshold <- 1
adjPval_threshold <- 0.05

# Step 8: Generate the heatmap with publication-ready styling
pheatmap(
  scaled_exp,
  annotation_col = sample_annotation,
  annotation_colors = annotation_colors,
  cluster_rows = TRUE,
  cluster_cols = TRUE,
  show_rownames = TRUE,
  show_colnames = TRUE,
  color = colorRampPalette(c("turquoise1", "white", "red"))(100),
  fontsize_row = 8,
  fontsize_col = 8,
  fontsize = 12,
  border_color = NA,
  main = "Heatmap of Differentially Expressed Genes\n(Astrocytoma vs NonTumor)"
)
# Out:
# plot without title

# %%
# Define thresholds for classification
logFC_threshold <- 1
adjPval_threshold <- 0.05

# Generate the heatmap with publication-ready styling
pheatmap(
  scaled_exp,
  annotation_col = sample_annotation_Glio,
  annotation_colors = annotation_colors,
  cluster_rows = TRUE,
  cluster_cols = TRUE,
  show_rownames = TRUE,
  show_colnames = TRUE,
  color = colorRampPalette(c("turquoise1", "white", "red"))(100),
  fontsize_row = 8,
  fontsize_col = 8,
  fontsize = 12,
  border_color = NA,
  main = "Heatmap of Differentially Expressed Genes\n(Glioblastoma vs NonTumor)"
# Out:
# plot without title
